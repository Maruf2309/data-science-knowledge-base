# %% [markdown]
# ```bash
#
# # 📌 Load Data
# df = pd.read_csv("file.csv")
#
# # 📌 Basic Info
# df.head()
# df.info()
# df.describe()
#
# # 📌 Select Columns
# df['col']
# df[['col1', 'col2']]
#
# # 📌 Filter
# df[df['age'] > 30]
#
# # 📌 GroupBy
# df.groupby('col')['target'].mean()
#
# # 📌 Sort
# df.sort_values(by='col')
#
# # 📌 Missing Values
# df.isnull().sum()
# df.fillna(0)
